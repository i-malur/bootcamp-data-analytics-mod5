# %% [markdown]
# <a href="https://colab.research.google.com/github/i-malur/bootcamp-data-analytics-mod5/blob/main/M%C3%B3dulo_05_%7C_DATA_WRANGLING.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Colab da aula: https://colab.research.google.com/drive/1rOrhbmdr5Vfiu3K8ME4e3mEL7pqcTJBE?usp=sharing

# %% [markdown]
# ## Aulas 01 e 02

# %%
import pandas as pd
import numpy as np

# %%
url_research = 'https://raw.githubusercontent.com/i-malur/bootcamp-data-analytics-mod5/refs/heads/main/arquivos-csv/reasearch_people.csv'

# %%
df_research_people = pd.read_csv(url_research)

# %%
df_research_people.head()
# Out:
#    Unnamed: 0                 Nome               Endereerço    Cidade  \
# 0           0   Maria Clara Novaes                      NaN  Carvalho
# 1           1  Davi Lucca Pereira>  Rodovia de Silveira, 67       NaN
# 2           2    Sr. Caio Caldeira  Residencial Freitas, 10  Carvalho
# 3           3      Kaique Azevedo%                      NaN   Azevedo
# 4           4        Pedro Moreira  Colônia de Oliveira, 87       NaN
#
#                 Estado            phone  anual_income Estado Civil  AAge  \
# 0   Mato Grosso do Sul  (011) 3908 5991       86445.0          NaN  43.0
# 1   Mato Grosso do Sul              NaN       31289.0          NaN   NaN
# 2  Rio Grande do Norte              NaN           NaN            S  60.0
# 3    Rio Grande do Sul              NaN       76264.0       Casado  26.0
# 4                  NaN       -0.'8--%/]       53295.0       Casado  60.0
#
#    n_filhos        Moradia Food_restrictions   streaming  \
# ...

# %%
df_research_people = df_research_people.drop(columns=['Unnamed: 0'])
df_research_people.head()
# Out:
#                   Nome               Endereerço    Cidade  \
# 0   Maria Clara Novaes                      NaN  Carvalho
# 1  Davi Lucca Pereira>  Rodovia de Silveira, 67       NaN
# 2    Sr. Caio Caldeira  Residencial Freitas, 10  Carvalho
# 3      Kaique Azevedo%                      NaN   Azevedo
# 4        Pedro Moreira  Colônia de Oliveira, 87       NaN
#
#                 Estado            phone  anual_income Estado Civil  AAge  \
# 0   Mato Grosso do Sul  (011) 3908 5991       86445.0          NaN  43.0
# 1   Mato Grosso do Sul              NaN       31289.0          NaN   NaN
# 2  Rio Grande do Norte              NaN           NaN            S  60.0
# 3    Rio Grande do Sul              NaN       76264.0       Casado  26.0
# 4                  NaN       -0.'8--%/]       53295.0       Casado  60.0
#
#    n_filhos        Moradia Food_restrictions   streaming  \
# 0       NaN        Quitada           Nenhuma  Globo Play
# 1       0.0       De favor               NaN       Todos
# ...

# %%
df_research_people = df_research_people.rename(columns={
    'Endereerço':'Endereço',
    'phone':'Telefone',
    'anual_income':'Renda Atual',
    'AAge':'Idade',
    'n_filhos': 'Numero de Filhos',
    'Food_restrictions':'Restrições Alimentares',
    'streaming':'Streaming',
    'diariamente_sun blocker':'Usa Protetor Solar Diariamente',
    'email':'Email'
})

df_research_people.columns
# Out:
# Index(['Nome', 'Endereço', 'Cidade', 'Estado', 'Telefone', 'Renda Atual',
#        'Estado Civil', 'Idade', 'Numero de Filhos', 'Moradia',
#        'Restrições Alimentares', 'Streaming', 'Usa Protetor Solar Diariamente',
#        'Vai na Praia Mensalmente', 'Faz Academia',
#        'Compra e Lê Livros Todos os Anos', 'Quantidade de Livros Comprados',
#        'Autor Favorito', 'Email'],
#       dtype='object')

# %% [markdown]
# Segunda opção:
#
# ```python
# novas_colunas = {
#     'Endereerço':'Endereço',
#     'phone':'Telefone',
#     'anual_income':'Renda Atual',
#     'AAge':'Idade',
#     'n_filhos': 'Numero de Filhos',
#     'Food_restrictions':'Restrições Alimentares',
#     'streaming':'Streaming',
#     'diariamente_sun blocker':'Usa Protetor Solar Diariamente',
#     'email':'Email'
# }
#
# df_research_people = df_research_people.rename(columns=df_research_people, inplace=True)
# ```
#
# inplace() -> serve para aplicar as alterações diretamente no DataFrame original, sem ter a necessidade de realizar uma cópia dele ou atribuí-lo novamente à variável

# %% [markdown]
# ### Regex
#
# Uma **Expressão Regular** (muito conhecida como **Regex** ou *Regular Expression*) é como se fosse um **super filtro de buscas** para textos.
#
# Em vez buscar por uma palavra exata (como "cachorro"), usamos um padrão de códigos para encontrar tipos de caracteres (como "qualquer número", "qualquer letra maiúscula" ou "qualquer símbolo").
#
# No código, o Pandas está usando o Regex para varrer o texto das colunas e fazer uma limpa.
#
# #### O que significa o `\W` especificamente?
#
# Na linguagem do Regex, os caracteres têm significados especiais. Existe uma diferença entre o **`\w`** (minúsculo) e o **`\W`** (maiúsculo):
#
# * **`\w` (minúsculo):** Representa caracteres de "palavras" (letras, números e o sublinhado `_`).
# * **`\W` (maiúsculo):** É o oposto direta do minúsculo. Ele representa **tudo o que NÃO é uma letra, número ou sublinhado**. Ou seja: espaços, pontos, vírgulas, arrobas (`@`), barras (`/`), traços (`-`), exclamações, etc.
#
# Portanto, quando é rodado:
#
# ```python
# df_research_people.str.replace('\W', '', regex=True)
#
# ```
#
# > *" O Python procura por tudo que for símbolo, pontuação ou espaço (`\W`) e **substitua por nada** (`''`), ou seja, apague tudo e deixe só as letras e números juntos."*
#
# #### Exemplos Práticos
#
# | Texto Original | O que o `\W` encontra | Resultado após o `.replace()` |
# | --- | --- | --- |
# | `João_Silva` | NADA (o `_` faz parte do `\w`) | `João_Silva` |
# | `João Silva` | O espaço em branco | `JoãoSilva` |
# | `R$ 1.500,00` | `$`, o espaço, os pontos e a vírgula | `R150000` |
# | `id-458/B` | O traço `-` e a barra `/` | `id458B` |
#
# Nas versões mais recentes do Pandas, para usar o Regex dentro do `.str.replace()`, é necessário passar o argumento `regex=True` explicitamente, caso contrário o Pandas pode achar que estamos tentando buscar literalmente pelo texto `\W`.
#
# O jeito mais seguro de escrever seria:
#
# ```python
# df_research_people.str.replace(r'\W', '', regex=True) -> necessário o r antes de '\W'
#
# ```

# %% [markdown]
# ### coluna Nome

# %%
# df_research_people['Nome'] = df_research_people['Nome'].str.replace(r'\W', '', regex=True)

# %%
# O ^ dentro do [^ ...] significa "NÃO".
# Remove números e símbolos, mantendo letras e espaços
df_research_people['Nome'] = df_research_people['Nome'].str.replace(r'[^a-zA-ZÀ-ÿ ]', '', regex=True)

# %%
df_research_people.head(5)
# Out:
#                  Nome                 Endereço    Cidade               Estado  \
# 0  Maria Clara Novaes                      NaN  Carvalho   Mato Grosso do Sul
# 1  Davi Lucca Pereira  Rodovia de Silveira, 67       NaN   Mato Grosso do Sul
# 2    Sr Caio Caldeira  Residencial Freitas, 10  Carvalho  Rio Grande do Norte
# 3      Kaique Azevedo                      NaN   Azevedo    Rio Grande do Sul
# 4       Pedro Moreira  Colônia de Oliveira, 87       NaN                  NaN
#
#           Telefone  Renda Atual Estado Civil  Idade  Numero de Filhos  \
# 0  (011) 3908 5991      86445.0          NaN   43.0               NaN
# 1              NaN      31289.0          NaN    NaN               0.0
# 2              NaN          NaN            S   60.0               NaN
# 3              NaN      76264.0       Casado   26.0               4.0
# 4       -0.'8--%/]      53295.0       Casado   60.0               5.0
#
#          Moradia Restrições Alimentares   Streaming  \
# ...

# %% [markdown]
# ### Coluna telefone

# %%
df_research_people['Telefone']
# Out:
# 0         (011) 3908 5991
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4              -0.'8--%/]
# 5     +55 (084) 4591-2403
# 6            84 9687 5023
# 7              5}|#:}~<7~
# 8        +55 51 6868 3666
# 9                     NaN
# 10                    NaN
# 11          0900 093 9760
# 12                    NaN
# 13           81 2891-7504
# 14             ^{{52$,,78
# 15                    NaN
# 16           41 5504 8546
# 17           84 2319-1532
# 18          0800 612 6032
# 19                    NaN
# 20           51 5882 5998
# 21                    NaN
# 22             ;~).,-:5~=
# 23    +55 (021) 4719 9862
# 24        (084) 0305 6725
# 25        (011) 3410 5199
# 26                    NaN
# 27           84 6014-5325
# 28                    NaN
# 29       +55 71 7088-8329
# 30                    NaN
# 31           21 0712-6859
# 32       +55 51 2213 5603
# 33             8:<$9@\:~/
# 34       +55 51 8245 2336
# ...

# %%
df_telefone = df_research_people['Telefone'].str.replace(r'[^0-9() +-]', '*', regex=True)

# %%
df_research_people.loc[df_telefone.str.contains('[*]', na=False), 'Telefone'] = np.nan

# %%
df_research_people.head(10)
# Out:
#                     Nome                   Endereço                 Cidade  \
# 0     Maria Clara Novaes                        NaN               Carvalho
# 1     Davi Lucca Pereira    Rodovia de Silveira, 67                    NaN
# 2       Sr Caio Caldeira    Residencial Freitas, 10               Carvalho
# 3         Kaique Azevedo                        NaN                Azevedo
# 4          Pedro Moreira    Colônia de Oliveira, 87                    NaN
# 5   Sra Ana Júlia Castro  Parque Olivia da Mata, 32  Nogueira dos Dourados
# 6         Erick Carvalho          Sítio Farias, 264                    NaN
# 7  Sra Ana Sophia Vieira    Esplanada de Mendes, 72                    NaN
# 8        Davi Nascimento             Rua da Paz, 72                 Duarte
# 9           Juan da Mota            Viela das Neves                    NaN
#
#                 Estado             Telefone  Renda Atual Estado Civil  Idade  \
# ...

# %% [markdown]
# ### Estado civil

# %%
df_research_people['Estado Civil'] = df_research_people['Estado Civil'].replace(
    {
        'V':'Viuvo',
        'D':'Divorciado',
        'S':'Solteiro',
        'C':'Casado'
    }
)

# %%
df_research_people['Telefone']
# Out:
# 0         (011) 3908 5991
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5     +55 (084) 4591-2403
# 6            84 9687 5023
# 7                     NaN
# 8        +55 51 6868 3666
# 9                     NaN
# 10                    NaN
# 11          0900 093 9760
# 12                    NaN
# 13           81 2891-7504
# 14                    NaN
# 15                    NaN
# 16           41 5504 8546
# 17           84 2319-1532
# 18          0800 612 6032
# 19                    NaN
# 20           51 5882 5998
# 21                    NaN
# 22                    NaN
# 23    +55 (021) 4719 9862
# 24        (084) 0305 6725
# 25        (011) 3410 5199
# 26                    NaN
# 27           84 6014-5325
# 28                    NaN
# 29       +55 71 7088-8329
# 30                    NaN
# 31           21 0712-6859
# 32       +55 51 2213 5603
# 33                    NaN
# 34       +55 51 8245 2336
# ...
